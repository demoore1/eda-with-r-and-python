# %% [markdown]
# # 02: Data Cleaning
#
# **Objective:** Identify and handle missing or invalid values, detect outliers, and standardize data for our recidivism dataset.
#
# **Key Steps:**
#
# <table width="100%">
#   <tr>
#     <td style="vertical-align: top; text-align: left; width: 60%; padding-right: 20px;">
#       <ol style="font-size: 20px; line-height: 1.4;">
#         <li>Identify &amp; quantify missing data</li>
#         <li>Handle missing values (imputation, removal, flagging)</li>
#         <li>Validate &amp; correct data types</li>
#         <li>Detect &amp; treat outliers</li>
#         <li>Standardize &amp; normalize</li>
#         <li>Document transformations</li>
#       </ol>
#     </td>
#     <td style="vertical-align: top; text-align: left; width: 40%;">
#       <!-- relative path to cleaning.png -->
#       <img src="../slides/cleaning.png" alt="Data Cleaning Image" width="1000" />
#     </td>
#   </tr>
# </table>
#
# ---
# <audio controls src="../audio/Cleaning.m4a">

# %% [markdown]
# Now that we’ve laid out our data‑cleaning roadmap, let’s put it into practice with a real dataset. For the rest of this lesson, we’ll work with the **COMPAS recidivism data** (`compas‑scores‑raw.csv`), which contains demographic and risk‑assessment scores for individuals screened by the COMPAS tool.
#
# We’ll start by running through each cleaning step in **Python**, then you are encouraged to repeat the same process in **R** so you can see both workflows side by side.

# %% [markdown]
# Now that we’ve laid out our data‑cleaning roadmap, let’s put it into practice with a real dataset. For the rest of this lesson, we’ll work with the **COMPAS recidivism data** (`compas‑scores‑raw.csv`), which contains demographic and risk‑assessment scores for individuals screened by the COMPAS tool.
#
# We’ll start by running through each cleaning step in **Python**, then you are encouraged to repeat the same process in **R** so you can see both workflows side by side.

# %% [markdown]
# ## Python
#
# Since this is your first time, you’ll need to download all of the little helper programs (called “packages”) we’ll use—just run one simple command to get them all at once:
#
# ```bash
# !pip install -r requirements_Python.txt

# %%
# only run this block your first time doing this training.

# !pip install -r ..\requirements_Python.txt
# Out:
# Requirement already satisfied: scikit-learn in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from -r ..\requirements_Python.txt (line 1)) (1.7.1)
# Requirement already satisfied: pandas in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from -r ..\requirements_Python.txt (line 2)) (2.3.1)
# Requirement already satisfied: numpy in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from -r ..\requirements_Python.txt (line 3)) (2.3.2)
# Requirement already satisfied: matplotlib in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from -r ..\requirements_Python.txt (line 4)) (3.10.3)
# Requirement already satisfied: jupyterlab in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from -r ..\requirements_Python.txt (line 5)) (4.4.5)
# Requirement already satisfied: scipy in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from -r ..\requirements_Python.txt (line 6)) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r ..\requirements_Python.txt (line 1)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r ..\requirements_Python.txt (line 1)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r ..\requirements_Python.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r ..\requirements_Python.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r ..\requirements_Python.txt (line 2)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ..\requirements_Python.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ..\requirements_Python.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ..\requirements_Python.txt (line 4)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ..\requirements_Python.txt (line 4)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ..\requirements_Python.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ..\requirements_Python.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ..\requirements_Python.txt (line 4)) (3.2.3)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (6.30.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.1.6)
# Requirement already satisfied: jupyter-core in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.2.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (80.9.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (6.5.1)
# Requirement already satisfied: traitlets in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r ..\requirements_Python.txt (line 5)) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (27.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (4.25.0)
# Requirement already satisfied: requests>=2.31 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.32.4)
# Requirement already satisfied: idna>=2.8 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (25.1.0)
# Requirement already satisfied: certifi in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (9.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (7.0.0)
# Requirement already satisfied: colorama in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=3.0.3->jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-core->jupyterlab->-r ..\requirements_Python.txt (line 5)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-core->jupyterlab->-r ..\requirements_Python.txt (line 5)) (311)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.21.1)
# Requirement already satisfied: six>=1.5 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r ..\requirements_Python.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (4.14.1)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.9.0.20250708)
# Requirement already satisfied: executing>=1.2.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\demoore\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab->-r ..\requirements_Python.txt (line 5)) (0.2.3)

# %% [markdown]
# #### Loading the Pandas Library
#
# Before we can work with our data in Python, we need to load the **Pandas** library. The line below does two things:
#
# 1. **Imports** the Pandas module so its functions and classes become available.
# 2. **Aliases** it as `pd` so we can reference it concisely in our code.
#
# ```python
# import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# ### 2.1 Identify & Quantify Missing Data
#
# First, load the data and get a sense of where values are missing.

# %%
df = pd.read_csv("../data/compas_scores_raw.csv")

# %% [markdown]
# Finally, we call .head() on the DataFrame to display the first five rows. This gives us a quick peek at the structure and contents of our dataset, including column names and sample values.

# %%
df.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 2      50855         57181    51963    PRETRIAL    DAYES    DANIEL        NaN
# 3      50855         57181    51963    PRETRIAL    DAYES    DANIEL        NaN
# 4      50850         57176    51958    PRETRIAL     Debe  Mikerlie     George
#
#   Sex_Code_Text  Ethnic_Code_Text  ScaleSet_ID  ...      MaritalStatus  \
# 0          Male         Caucasian           22  ...             Single
# 1          Male         Caucasian           22  ...            Married
# 2          Male  African-American           22  ...             Single
# 3          Male  African-American           22  ...             Single
# 4        Female  African-American           22  ...  Significant Other
#
#   RecSupervisionLevel RecSupervisionLevelText Scale_ID  \
# 0                   1                     Low       18
# 1                   1                     Low       18
# 2                   4                    High        8
# 3                   4                    High       18
# 4                   2                  Medium       18
#
#                  DisplayText  RawScore DecileScore  ScoreText AssessmentType  \
# 0  Risk of Failure to Appear     15.00           1        Low            New
# 1  Risk of Failure to Appear     19.00           3        Low            New
# 2         Risk of Recidivism      0.18           8       High            New
# 3  Risk of Failure to Appear     13.00           1        Low            New
# 4  Risk of Failure to Appear     11.00           1        Low            New
#
#     Age
# 0  20.0
# 1  28.0
# 2  18.0
# 3  18.0
# 4  18.0
#
# [5 rows x 24 columns]

# %% [markdown]
# > **What to look for in the output:**
# > - **Column names** such as `Person_ID`, `Case_ID`, `LastName`, `FirstName`, `MiddleName`, `Sex_Code_Text`, `Ethnic_Code_Text`, `RawScore`, `DecileScore`, `ScoreText`, `Age`
# > - **Data types** (numeric vs. categorical) and any surprising or missing values
# > - **Structure** of the dataset—how it's organized before we begin cleaning and analysis

# %% [markdown]
# Now that we’ve successfully loaded the COMPAS dataset into our `df` object, it’s time to get a quick overview of its structure. In the next step, we’ll check how big the table is and see where any missing values might be hiding.

# %% [markdown]
# #### Checking Dataset Size and Missing Data
#
# In this step, we first look at the overall size of our dataset and then count any empty or missing values:

# %%
  print(f"Dataset shape: {df.shape}")
# Out:
# Dataset shape: (24272, 24)

# %% [markdown]
#  **What does the output mean?**
#
#  - **Dataset shape**
#    This tells us how many rows (records) and columns (fields) we have.
#    For example, `(24272, 24)` means 24,072 rows and 24 columns.

# %% [markdown]
# ### 2.2 Handle Missing Values
#
# #### Counting Missing Values
#
# First, let’s see which columns have missing data and how many blanks each contains:

# %%
missing = df.isna().sum()
print("Missing values per column:")
print(missing[missing > 0])
# Out:
# Missing values per column:
# MiddleName    17942
# ScoreText        45
# Age              56
# dtype: int64

# %% [markdown]
# #### Options for Handling Missing Values
# - **Removal:** drop rows or columns with too many nulls
# - **Imputation:** fill with mean/median or a constant
#
# ##### MiddleName: 17,942 missing values
#   Most records don’t include a middle name—since this field isn’t critical to our analysis, we’ll drop the entire column.
#
# ##### ScoreText: 45 missing values
#   A small number of records lack the textual risk label. We’ll remove any rows where `ScoreText` is missing, since we need that label for downstream analyses.
#
# ##### Age: 56 missing values
#   A handful of entries are missing age information. Since age is important for our analysis, we’ll impute these missing ages with the median age value.
#
# By printing only `missing[missing > 0]`, we focus on the columns that actually have missing entries, allowing us to target our cleaning efforts precisely.
#
# Below we’ll:
# 1. Drop columns with >50% missing
# 2. Impute `Age` with the median

# %% [markdown]
# ##### Step 1: Drop Mostly Empty Columns
#
# Our dataset has a “MiddleName" column that’s almost entirely blank. To avoid clutter, we remove any column where more than half of its values are missing. This will automatically drop “MiddleName” and any other mostly empty fields.

# %%
threshold = len(df) * 0.5
df = df.dropna(axis=1, thresh=threshold)

# %% [markdown]
# ##### Step 2: Remove Rows with Blank `ScoreText` and Fill Missing `Age`
#
# First, we drop any rows where `ScoreText` is blank, since those entries don’t tell us whether someone was classified as “Low,” “Medium,” or “High” risk. After that, we flag rows with missing `Age`, compute the median age, and fill those gaps.

# %%
# 1. Drop rows where ScoreText is blank
df = df[df["ScoreText"].str.strip() != ""]

# 2. Flag rows where Age was missing
df["age_missing"] = df["Age"].isna()

# 3. Compute median Age and fill missing ages
median_age = df["Age"].median()
df["Age"] = df["Age"].fillna(median_age)

# %% [markdown]
# ##### Now we have:
# - Removed all rows lacking a valid risk category in `ScoreText`.
# - Marked originally missing `Age` values in a new `age_missing` column.
# - Filled those missing ages with the dataset’s median age.

# %% [markdown]
# ### 2.3 Validate & Correct Data Types
#
# Before we go further, let’s make sure each column uses the right data type:
#
# - Numbers as integers or floats
# - Dates as datetime objects
# - Text fields we’ll analyze categorically as “category”

# %%
# Convert Score and Age to integers
df["RawScore"]    = df["RawScore"].astype(int)
df["DecileScore"] = df["DecileScore"].astype(int)
df["Age"]         = df["Age"].astype(int)


# Convert text fields to categorical
for col in [
    "ScoreText", "Sex_Code_Text", "Ethnic_Code_Text",
    "Language", "MaritalStatus", "RecSupervisionLevelText"
]:
    df[col] = df[col].astype("category")

# Verify types without any warnings
df.dtypes
# Out:
# Person_ID                     int64
# AssessmentID                  int64
# Case_ID                       int64
# Agency_Text                  object
# LastName                     object
# FirstName                    object
# Sex_Code_Text              category
# Ethnic_Code_Text           category
# ScaleSet_ID                   int64
# ScaleSet                     object
# Language                   category
# LegalStatus                  object
# CustodyStatus                object
# MaritalStatus              category
# RecSupervisionLevel           int64
# RecSupervisionLevelText    category
# Scale_ID                      int64
# DisplayText                  object
# RawScore                      int64
# DecileScore                   int64
# ScoreText                  category
# AssessmentType               object
# Age                           int64
# age_missing                    bool
# dtype: object

# %% [markdown]
# > **What we’ve done:**
# > - Forced `RawScore`, `DecileScore`, and `Age` into integer form
# > - Marked risk categories and demographic fields as categorical
# > - Verified the changes by inspecting `df.dtypes`

# %% [markdown]
# ### Step 2.4: Find and Remove Extreme Values (Outliers) in `RawScore`
#
# Even smart data can hide a few extreme values—called **outliers**—that skew our insights. We’ll clean those out by:
#
# 1. **Sorting** all `RawScore` values and finding the 25th percentile (Q1) and 75th percentile (Q3).
# 2. Calculating the **interquartile range (IQR)** = Q3 − Q1, which covers the middle 50% of the data.
# 3. Defining an **acceptable range** as   [Q1 − 3×IQR, Q3 + 3×IQR]
# 4. **Keeping** only rows with `RawScore` inside that range and dropping the rest.
#
# This preserves most of the data while removing the very highest or lowest scores that could mislead our analysis.

# %%
# 1. Calculate Q1 (25th percentile) and Q3 (75th percentile) for RawScore
Q1 = df["RawScore"].quantile(0.25)
Q3 = df["RawScore"].quantile(0.75)

# 2. Compute the IQR
IQR = Q3 - Q1

# 3. Define acceptable lower and upper bounds
lower_bound = Q1 - 3 * IQR
upper_bound = Q3 + 3 * IQR

# 4. Filter the dataframe to keep only non-outliers
df_clean = df[(df["RawScore"] >= lower_bound) & (df["RawScore"] <= upper_bound)]

# 5. Report how many rows we kept versus removed
print(f"Rows before cleaning: {len(df)}")
print(f"Rows after removing outliers: {len(df_clean)}")
# Out:
# Rows before cleaning: 24272
# Rows after removing outliers: 24263

# %% [markdown]
# > **In plain terms:**
# > - We measured how wide the middle 50% of scores is.
# > - We dropped any scores more than three times that range away from the center.
# > - Now `df_clean` has most of our original rows minus the extreme cases that could distort averages or trends.

# %% [markdown]
# ### Step 2.5: Standardize & Normalize Key Variables
#
# Some analysis methods work best when numbers share a common scale. We’ll use two popular Python libraries:
#
# - **SciPy** (`scipy`): a scientific computing library that includes statistical functions, like calculating z‑scores.
# - **scikit‑learn** (`sklearn`): a machine‑learning library that provides tools for data preprocessing, including min‑max scaling.
#
# Here’s what we’ll do:
#
# 1. **Z‑score Standardization** on `Age`
#    - Subtract the average age, then divide by the age’s standard deviation
#    - Result is a new column `age_z` where most values fall between –3 and +3
#
# 2. **Min‑Max Scaling** on `RawScore`
#    - Rescales `RawScore` to lie between 0 (lowest score) and 1 (highest score)
#    - Result is a new column `rawscore_scaled` that preserves relative differences
#
# We’ll apply both to our cleaned data in `df_clean`.

# %%
from scipy import stats
from sklearn.preprocessing import MinMaxScaler

# 1. Z‑score standardization on Age
df_clean.loc[:, "age_z"] = stats.zscore(df_clean["Age"])

# 2. Min‑max scaling on RawScore
scaler = MinMaxScaler()
df_clean.loc[:, "rawscore_scaled"] = scaler.fit_transform(df_clean[["RawScore"]])

# Show the new columns alongside the originals
df_clean[["Age", "age_z", "RawScore", "rawscore_scaled"]].head()
# Out:
# C:\Users\demoore\AppData\Local\Temp\ipykernel_29496\2835621474.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.loc[:, "age_z"] = stats.zscore(df_clean["Age"])
# C:\Users\demoore\AppData\Local\Temp\ipykernel_29496\2835621474.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.loc[:, "rawscore_scaled"] = scaler.fit_transform(df_clean[["RawScore"]])
#    Age     age_z  RawScore  rawscore_scaled
# 0   20 -1.057784        15         0.333333
# 1   28 -0.387237        19         0.422222
# 2   18 -1.225421         0         0.000000
# 3   18 -1.225421        13         0.288889
# 4   18 -1.225421        11         0.244444

# %% [markdown]
# ## Interpreting Our Transformed Data
#
#
#
# | Age | age_z | RawScore | rawscore_scaled |
# | --- | ----- | -------- | --------------- |
# | 20  | -1.057784 | 15       | 0.3333      |
# | 28  | -0.387237 | 19       | 0.4222      |
# | 18  | -1.225421 | 0        | 0.0000      |
# | 18  | -1.225421 | 13       | 0.2888      |
#
# ### What each column is
#
# - **Age**
#   The actual age in years
#
# - **age_z**
#   A “z‑score” shows how far each age is from the average age, measured in standard units
#   - 0 means exactly average
#   - Negative means below average
#   - Positive means above average
#   - −-1.05778 means about -1.05778 units younger than average
#
# - **RawScore**
#   The original score before any changes (for example a test result or rating)
#
# - **rawscore_scaled**
#   The RawScore rescaled to lie between 0 and 1
#   - 0 is the lowest RawScore in our group
#   - 1 is the highest RawScore in our group
#   - 0.03 means very close to the lowest
#   - 0.29 means 29 percent of the way from lowest to highest
#
# ### Why we do this
#
# 1. **Fair comparison**
#    When columns use very different units or ranges our analysis can get biased. Standardizing and scaling puts all numbers on the same footing.
#
# 2. **Better results**
#    Many data tools and machine learning methods work best when inputs live on the same scale.
#
# 3. **Clear interpretation**
#    - Z‑scores tell us how far a value is from the average in comparable units
#    - Scaled scores between 0 and 1 make it easy to see relative position without worrying about original units
#
# ---
#
# In plain terms, we’ve “translated” every number so they all speak the same language. That helps our next analysis steps work properly and gives you a fair way to compare apples to apples.

# %% [markdown]
# ### Step 2.6: Record Your Cleaning Steps
#
# Finally, it’s best practice to keep a log of every transformation. Below we build a simple dictionary summarizing what we did:
#
# - Which columns we dropped because they were mostly empty
# - The median age we used for imputation
# - The bounds we used to remove outliers in `RawScore`
# - Which columns we standardized and normalized
#
# At the end, we print this log in a clear, readable format.

# %%
# Build a list of (Step, Details)
log_items = [
    ("Dropped Columns", list(missing[missing > threshold].index)),
    ("Imputed Age", median_age),
    ("Outlier Bounds (RawScore)", (lower_bound, upper_bound)),
    ("Standardized", ["age_z"]),
    ("Normalized", ["rawscore_scaled"])
]

# Turn it into a DataFrame and display
log_df = pd.DataFrame(log_items, columns=["Step", "Details"])
display(log_df)
# Out:
#                         Step            Details
# 0            Dropped Columns       [MiddleName]
# 1                Imputed Age               29.0
# 2  Outlier Bounds (RawScore)      (-11.0, 45.0)
# 3               Standardized            [age_z]
# 4                 Normalized  [rawscore_scaled]

# %% [markdown]
#  **How to read this table:**
#  - **Step:** what we did
#  - **Details:** the exact values or columns affected by that step
#
#
# > **Why this matters:**
# > A clear transformation log makes your work reproducible and lets others (or future you) understand exactly how the data was prepared before any analysis or modeling.

# %% [markdown]
# ## Next Steps: Continue in Python or Switch to R
#
# Our data is now clean and properly formatted. You have two options:
#
# 1. **Try the R version** of this cleaning workflow by opening `02_data_cleaning_R.ipynb`.
# 2. **Move on to summary statistics in Python** by opening `03_summary_statistics_Python.ipynb`.
#
# Choose the notebook that matches your preferred language, and let’s continue exploring our recidivism dataset!
